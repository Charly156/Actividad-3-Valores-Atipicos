# %% [markdown]
# <a href="https://colab.research.google.com/github/Charly156/Actividad-3-Valores-Atipicos/blob/main/Actividad_Valores_Atipicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Se importan las bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Se lee la base de datos
data = pd.read_csv('Ventas_totales_limpio.csv')

#Se elimina una columna que esta demás
data= data.drop(columns = ['Unnamed: 0'])
data
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Corroboramos valores nulos de la base de datos para poder analizar los datos
valores_nulos = data.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
#Se hace una copia del dataframe por seguridad
data1 = data.copy()

# %%
#Usamos la grafica de boxplot en una de las columnas para ver su distribución
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['subtotal_ventas_alimentos_bebidas'])
plt.title('Subtotal de ventas de alimentos y bebidas')
plt.grid()

# %%
#Viendo que hay outliers en la gráfica, se usa el
#método de cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['subtotal_ventas_alimentos_bebidas']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

Limite_superior_iqr = percentile75 + 1.5 * iqr
Limite_inferior_iqr = percentile25 - 1.5 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 114548006.925
# Limite inferior permitido -11790048.954999998

# %%
#Obtenemos datos limpios y los almacenamos en otra variable
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
registro1 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 56    01/09/2021                   123002.3                    22962.0
# 57    01/10/2021                   140487.5                    25386.7
# 58    01/11/2021                   141702.0                    25026.6
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Se crea la caja de boxplot con los datos limpios
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['subtotal_ventas_alimentos_bebidas'])
plt.title('Subtotal de ventas de alimentos y bebidas')
plt.grid()
plt.show()

# %% [markdown]
# ##Se repite el proceso

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['tarjetas_debito'])
plt.title('Tarjetas de debito')
plt.grid()

# %%
#Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['tarjetas_debito']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Debido a lo juntos que estan los datos se reduce el valor de los quantiles
Limite_superior_iqr = percentile75 + 1.1 * iqr
Limite_inferior_iqr = percentile25 - 1.1 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 44322078.8199
# Limite inferior permitido -8719023.2889

# %%
#Se filtran los datos
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]

#Se crea la copia de los datos limpios
registro2 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# 5     01/06/2017                    29132.7                    26365.4
# 6     01/07/2017                    31182.3                    27819.4
# 7     01/08/2017                    31154.9                    27394.1
# 8     01/09/2017                    30521.5                    26404.3
# 9     01/10/2017                    32446.0                    27766.7
# 10    01/11/2017                    33629.0                    28425.3
# 11    01/12/2017                    40766.3                    34084.5
# ...

# %%
#Se imprime los datos limpios en forma de boxplot
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['tarjetas_debito'])
plt.title('Tarjetas de debito')
plt.grid()
plt.show()

# %% [markdown]
# ##Tercer gráfico

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['ventas_precios_corrientes'])
plt.title('Ventas de los precios corrientes')
plt.grid()

# %%
#Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['ventas_precios_corrientes']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Debido a lo cercanos que están los datos se tienen que reducir
#los límites
Limite_superior_iqr = percentile75 + 1.2 * iqr
Limite_inferior_iqr = percentile25 - 1.2 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 173457.0
# Limite inferior permitido -40316.30000000001

# %%
#Se limpian los datos al filtrar lo que esta en los parámetros
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]

#Se almacenan los datos limpios en una variable
registro3 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 57    01/10/2021                   140487.5                    25386.7
# 58    01/11/2021                   141702.0                    25026.6
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Se grafican los datos limpios
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['ventas_precios_corrientes'])
plt.title('Ventas de los precios corrientes')
plt.grid()
plt.show()

# %% [markdown]
# ##Cuarto gráfico

# %%
#Se grafica los datos de una columna distinta
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['ventas_precios_constantes'])
plt.title('Ventas de los precios constantes')
plt.grid()

# %%
#Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['ventas_precios_constantes']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Debido a lo compacto de los datos se reduce el tamaño de los límites
Limite_superior_iqr = percentile75 + 1.2 * iqr
Limite_inferior_iqr = percentile25 - 1.2 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 30950.34
# Limite inferior permitido 19748.36

# %%
#Se registran los datos filtrados y se almacenan en registro4
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
registro4 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# 5     01/06/2017                    29132.7                    26365.4
# 6     01/07/2017                    31182.3                    27819.4
# 7     01/08/2017                    31154.9                    27394.1
# 8     01/09/2017                    30521.5                    26404.3
# 9     01/10/2017                    32446.0                    27766.7
# 10    01/11/2017                    33629.0                    28425.3
# 12    01/01/2018                    32479.2                    26736.7
# ...

# %%
#Se grafican los datos nuevos por medio de una gráfica de cajas
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['ventas_totales_canal_venta'])
plt.title('Ventas totales del canal de venta')
plt.grid()
plt.show()

# %% [markdown]
# ##Quinto gráfico

# %%
#Se grafican los datos de la variable del salón de ventas
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['salon_ventas'])
plt.title('Salón de ventas')
plt.grid()

# %%
#Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['salon_ventas']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Para que los datos se registran bien solo se tiene que disminuir
#los límites aunque no se recumienda debido a las especificaciones
#estandar
Limite_superior_iqr = percentile75 + 1.0 * iqr
Limite_inferior_iqr = percentile25 - 1.0 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 145134903.48
# Limite inferior permitido -6696171.149999991

# %%
#Se filtran los datos y se registran en una nueva variable
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
registro5 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# 5     01/06/2017                    29132.7                    26365.4
# 6     01/07/2017                    31182.3                    27819.4
# 7     01/08/2017                    31154.9                    27394.1
# 8     01/09/2017                    30521.5                    26404.3
# 9     01/10/2017                    32446.0                    27766.7
# 10    01/11/2017                    33629.0                    28425.3
# 11    01/12/2017                    40766.3                    34084.5
# ...

# %%
#Se grafican los datos limpios
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['salon_ventas'])
plt.title('Salón de ventas')
plt.grid()
plt.show()

# %% [markdown]
# ##Sexto gráfico

# %%
#Se grafica otra variable para ver los outliers presentes
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['tarjetas_credito'])
plt.title('Tarjetas de crédito')
plt.grid()

# %%
#Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['tarjetas_credito']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Se reduce un poco los límites del iqr para poder filtrar los
#datos limpios
Limite_superior_iqr = percentile75 + 1.4 * iqr
Limite_inferior_iqr = percentile25 - 1.4 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 64073771.455999985
# Limite inferior permitido -16410662.085999992

# %%
#Los datos llegan a ser filtrados y posteriormente almacenados en una nueva
#variable
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
registro6 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 58    01/11/2021                   141702.0                    25026.6
# 59    01/12/2021                   183983.2                    31595.7
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Luego se llega a graficar la nueva gráfica de cajas
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['tarjetas_credito'])
plt.title('Tarjetas de crédito')
plt.grid()

# %% [markdown]
# ##Septimo gráfico

# %%
#Se grafican los datos de la variable bebida en una gráfica de cajas
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['bebidas'])
plt.title('Bebidas')
plt.grid()

# %%
#Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['bebidas']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Debido a la organización de los datos, se respeta el estándar
#para determinar los límites superiores e inferiores del iqr
Limite_superior_iqr = percentile75 + 1.5 * iqr
Limite_inferior_iqr = percentile25 - 1.5 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 22825184.4515
# Limite inferior permitido -6724636.7525

# %%
#Los datos son registrados un un nuevo DataFrame y luego son almacenados
#en una nueva variable
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
registro7 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Finalmente se grafican los datos limpios
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['bebidas'])
plt.title('Bebidas')
plt.grid()

# %% [markdown]
# ##Octavo gráfico

# %%
#Se usa la variable de panaderia en la que se pueden identificar varios outliers
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['panaderia'])
plt.title('Panadería')
plt.grid()

# %%
#Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['panaderia']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Debido a la densidad de algunos datos se tiene que disminuir el límite
Limite_superior_iqr = percentile75 + 1.3 * iqr
Limite_inferior_iqr = percentile25 - 1.3 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 5002230.736199999
# Limite inferior permitido -616644.3821999999

# %%
#Se crea una variable para almacenar los datos filtrados/limpios
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
registro8 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# 5     01/06/2017                    29132.7                    26365.4
# 6     01/07/2017                    31182.3                    27819.4
# 7     01/08/2017                    31154.9                    27394.1
# 8     01/09/2017                    30521.5                    26404.3
# 9     01/10/2017                    32446.0                    27766.7
# 10    01/11/2017                    33629.0                    28425.3
# 11    01/12/2017                    40766.3                    34084.5
# ...

# %%
#Se grafican los datos limpios de la variable panaderia
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['panaderia'])
plt.title('Panadería')
plt.grid()

# %% [markdown]
# ##Gráfico 9

# %%
#Se grafica la variable de lacteos en donde se puede
#apreciar que existen outliers
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['lacteos'])
plt.title('Lacteos')
plt.grid()

# %%
#Método aplicando cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data1['lacteos']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Debido a la distribución se pueden usar los límites estandar
Limite_superior_iqr = percentile75 + 1.5 * iqr
Limite_inferior_iqr = percentile25 - 1.5 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 19940661.0455
# Limite inferior permitido -5569362.3025

# %%
#Los datos son limpiados y posteriormente almacenados en una nueva variable
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
registro9 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 59    01/12/2021                   183983.2                    31595.7
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Se grafica la nueva base de datos en gráfica de cajas
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['lacteos'])
plt.title('Lacteos')
plt.grid()

# %% [markdown]
# ##Gráfico 10

# %%
#Se grafican los datos
fig = plt.figure(figsize = (10,6))
plt.boxplot(data['alimentos_preparados_rotiseria'])
plt.title('Alimentos preparados y rostisería')
plt.grid()

# %%
y = data1['alimentos_preparados_rotiseria']

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

#Debido a la dirtribución de los datos se tiene que cerrar más
#los límites
Limite_superior_iqr = percentile75 + 0.7 * iqr
Limite_inferior_iqr = percentile25 - 0.7 * iqr
print('Limite superior permitido', Limite_superior_iqr)
print('Limite inferior permitido', Limite_inferior_iqr)
# Out:
# Limite superior permitido 1191938.15211
# Limite inferior permitido 127499.19219000009

# %%
#Se registran los datos limpios y se colocan en la variable nueva
data_clean_iqr = data1[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
registro10 = data_clean_iqr.copy()
data_clean_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# 5     01/06/2017                    29132.7                    26365.4
# 6     01/07/2017                    31182.3                    27819.4
# 7     01/08/2017                    31154.9                    27394.1
# 8     01/09/2017                    30521.5                    26404.3
# 9     01/10/2017                    32446.0                    27766.7
# 10    01/11/2017                    33629.0                    28425.3
# 11    01/12/2017                    40766.3                    34084.5
# ...

# %%
#Se grafican los datos limpios
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['alimentos_preparados_rotiseria'])
plt.title('Alimentos preparados y rostisería')
plt.grid()

# %%
registro1.to_csv('Base limpia 1.csv')
registro2.to_csv('Base limpia 2.csv')
registro3.to_csv('Base limpia 3.csv')
registro4.to_csv('Base limpia 4.csv')
registro5.to_csv('Base limpia 5.csv')
registro6.to_csv('Base limpia 6.csv')
registro7.to_csv('Base limpia 7.csv')
registro8.to_csv('Base limpia 8.csv')
registro9.to_csv('Base limpia 9.csv')
registro10.to_csv('Base limpia 10.csv')
